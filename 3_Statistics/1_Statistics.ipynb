# %% [markdown]
# ## Statistics
#
# Statistics is the science of collecting, Organizing(Decision making), and Analyzing data .

# %% [markdown]
# ## Data
# Dita is "Facts or piece of Information" that can be measured , collected and analyzed .
#
# Eg : Weight of Students in a class
#    {60kg,65kg,63kg,68kg }
#    IQ of the student of class
#    {100,90,98,94,90}

# %% [markdown]
# ## House price dataset
# city           Area         no. of rooms        price
# banglore       1000            2                45

# %%
## Data
